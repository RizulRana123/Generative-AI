# %% [markdown]
# <a href="https://colab.research.google.com/github/RizulRana123/Generative-AI/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#flotimg point number--presence of decimal point
#ex 3.14, 6.98
x = 3.14
type(x)
# Out:
# float

# %%
#string--date in the form of text
x = "solan"
type(x)
# Out:
# str

# %%
#boolean-- it is used to store value in the form of true and false
a = True
type(a)
# Out:
# bool

# %%
b = False
type(b)
# Out:
# bool

# %%
#None-- define the null value means nothing
e = None
type(e)
# Out:
# NoneType
